# %%
pip3 install folium
# Out:
#   File "<ipython-input-7-4530be11b4dd>", line 1
#     pip3 install folium
#          ^
# SyntaxError: invalid syntax

# %%
import folium

# %%
fmap = folium.Map(location=[35.473619099083784, 138.57622543781568], zoom_start=16)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#圓框標示
center_pos = [35.473619099083784, 138.57622543781568]
fmap = folium.Map(location=center_pos, zoom_start=16)
fmap.add_child(folium.Circle(location=center_pos,
                             color='#84ffd8', # Circle 顏色
                             radius=1000, # Circle 寬度
                             popup='本栖湖キャンプ区', # 彈出視窗內容
                             fill=True, # 填滿中間區域
                             fill_opacity=0.3 # 設定透明度
                             ))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#圓框標示
center_pos = [35.473619099083784, 138.57622543781568]
fmap = folium.Map(location=center_pos, zoom_start=16)
fmap.add_child(folium.Circle(location=center_pos,
                             color='#84ffd8', # Circle 顏色
                             radius=1000, # Circle 寬度
                             popup='本栖湖キャンプ区', # 彈出視窗內容
                             fill=True, # 填滿中間區域
                             fill_opacity=0.3 # 設定透明度
                             ))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#圓框標示
center_pos = [35.473619099083784, 138.57622543781568]
fmap = folium.Map(location=center_pos, zoom_start=16)

m1 = folium.Marker(location=[35.47378469336976, 138.5720254176848],
                   popup='<b>kouan</b>',
                  icon=folium.Icon(icon='bed', 
                                    color='green',
                                    prefix='fa'))

m2 = folium.Marker(location=[35.473572024583106, 138.5737109656563],
                   popup='<i>camp</i>',
                   icon=folium.Icon(icon='tree', # Icon類型
                                    color='lightblue', # Marker顏色
                                    prefix='fa')) # 使用Font Awesome Icons

m3 = folium.Marker(location=[35.47622067756354, 138.5737109656563],
                   popup='<b>nakasaka</b>',
                   icon=folium.Icon(icon='circle',
                                    color='darkred',prefix='fa'))
# 將各Marker加入地圖。
fmap.add_child(child=m1)
fmap.add_child(child=m2)
fmap.add_child(child=m3)
fmap.add_child(folium.Circle(location=center_pos,
                             color='#84ffd8', # Circle 顏色
                             radius=1000, # Circle 寬度
                             popup='motosuko', # 彈出視窗內容
                             fill=True, # 填滿中間區域
                             fill_opacity=0.3 # 設定透明度
                             ))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#圓框標示
center_pos = [35.473619099083784, 138.57622543781568]
fmap = folium.Map(location=center_pos, zoom_start=16)

m1 = folium.Marker(location=[35.47378469336976, 138.5720254176848],
                   popup='<b>kouan</b>',
                  icon=folium.Icon(icon='bed', 
                                    color='green',
                                    prefix='fa'))

m2 = folium.Marker(location=[35.476861298719314, 138.59236172540577],
                   popup='<i>camp</i>',
                   icon=folium.Icon(icon='tree', # Icon類型
                                    color='lightblue', # Marker顏色
                                    prefix='fa')) # 使用Font Awesome Icons

m3 = folium.Marker(location=[35.47622067756354, 138.5737109656563],
                   popup='<b>nakasaka</b>',
                   icon=folium.Icon(icon='circle',
                                    color='darkred',prefix='fa'))

points = [[35.47378469336976, 138.5720254176848],
          [35.476861298719314, 138.59236172540577],
          [35.47622067756354, 138.5737109656563],
         [35.47378469336976, 138.5720254176848]]



# 將各child加入地圖。
fmap.add_child(folium.PolyLine(locations=points, # 座標List
                               color='black',
                               weight=5)) # 線條寬度


fmap.add_child(child=m1)
fmap.add_child(child=m2)
fmap.add_child(child=m3)
fmap.add_child(folium.Circle(location=center_pos,
                             color='#84ffd8', # Circle 顏色
                             radius=1650, # Circle 寬度
                             popup='motosuko', # 彈出視窗內容
                             fill=True, # 填滿中間區域
                             fill_opacity=0.3 # 設定透明度
                             ))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#center_pos = [35.473619099083784, 138.57622543781568]

import numpy as np
from folium.plugins import HeatMap

fmap = folium.Map(location=center_pos, zoom_start=16)

data = (np.random.normal(size=(100, 3)) * 0.02 *
        np.array([[1, 1, 1]]) +
        np.array([[35.473619099083784, 138.57622543781568, 1]])).tolist()

fmap.add_child(HeatMap(data=data))
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
df = pd.read_csv("./foliumtestdata.csv")
df
# Out:
#    No     lat      lon     pop   yurusa
# 0   1  35.473  135.576   10000     5000
# 1   2  35.533  135.777  500000  7777777
# 2   3  35.300  135.400     300   776677
# 3   4  35.515  135.441   12112    88888
# 4   5  35.417  135.808  777777  7574764
# 5   6  35.667  135.678  123456  1234567
# 6   7  36.777  135.888  234567  2345678

# %%
import pandas as pd
df = pd.read_csv("./台北市合法八大行業清冊.csv")
df.head(5)
# Out:
#    序號  公司/商業名稱      統一編號  負責人       經營行業  行政區  \
# 0   1  金桃源音樂餐廳  48705180  王彩鳳      視聽歌唱業  中正區
# 1   2   鴻欣視聽歌城  48736607  陳朝仁  酒吧業 視聽歌唱業  中山區
# 2   3   金世紀視聽社  48558820  萬善成      視聽歌唱業  中山區
# 3   4     元富名店  99957758  林子隆  酒吧業 視聽歌唱業  中山區
# 4   5   金碧輝煌酒店  99981201  謝志雄  酒吧業 視聽歌唱業  中山區
#
#                                        營業場所地址
# 0                                  桃源街１３號地下１樓
# 1                    長安東路１段２３號Ｂ１樓之１之２之３之４之５之６
# 2                                   松江路１８５號３樓
# 3  臺北市中山區林森北路２８９號３樓、３樓之１、之２、之３、之５、之６、之７、之８、之９
# 4  臺北市中山區林森北路２８９號２樓及２樓之１、之２、之３、之５、之６、之７、之８、之９

# %%
#center_pos = [35.473619099083784, 138.57622543781568]
import numpy as np
import pandas as pd
import seaborn as sns
import folium
import webbrowser
from folium.plugins import HeatMap


#center_pos = [35.473619099083784, 138.57622543781568]
#fmap = folium.Map(location=center_pos, zoom_start=16)

posi=pd.read_excel("./foliumtestdata.xlsx")

num = 10

lat = np.array(posi["lat"][0:num])                        # 獲取維度之維度值
lon = np.array(posi["lon"][0:num])                             # 獲取經度值
pop = np.array(posi["pop"][0:num],dtype=float)     # 獲取人口數，轉化為numpy浮點型
yrs = np.array(posi["yurusa"][0:num],dtype=float)   # 獲取yurusa數，轉化為numpy浮點型

data1 = [[lat[i],lon[i],pop[i]] for i in range(num)]  

map_osm = folium.Map(location=[35,138],zoom_start=5)    #繪製Map，開始縮放程度是5倍
HeatMap(data1).add_to(map_osm)  # 將熱力圖新增到前面建立的map裡
map_osm
# Out:
# -----------------------------------------------------------------------
# IndexError                            Traceback (most recent call last)
# <ipython-input-20-26552615de2a> in <module>
#      20 yrs = np.array(posi["yurusa"][0:num],dtype=float)   # 獲取yurusa數，轉化為numpy浮點型
#      21
# ---> 22 data1 = [[lat[i],lon[i],pop[i]] for i in range(num)]
#      23
#      24 map_osm = folium.Map(location=[35,138],zoom_start=5)    #繪製Map，開始縮放程度是5倍
#
# <ipython-input-20-26552615de2a> in <listcomp>(.0)
#      20 yrs = np.array(posi["yurusa"][0:num],dtype=float)   # 獲取yurusa數，轉化為numpy浮點型
#      21
# ---> 22 data1 = [[lat[i],lon[i],pop[i]] for i in range(num)]
#      23
#      24 map_osm = folium.Map(location=[35,138],zoom_start=5)    #繪製Map，開始縮放程度是5倍
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import folium
import webbrowser
from folium.plugins import HeatMap
# posi=pd.read_csv("D:\\Files\\datasets\\CitiesLatLon_China.csv")

posi=pd.read_excel("2015Cities-CHINA.xlsx")

num = 10

lat = np.array(posi["lat"][0:num])                        # 獲取維度之維度值
lon = np.array(posi["lon"][0:num])                        # 獲取經度值
pop = np.array(posi["pop"][0:num],dtype=float)    # 獲取人口數，轉化為numpy浮點型
gdp = np.array(posi["GDP"][0:num],dtype=float)    # 獲取人口數，轉化為numpy浮點型

data1 = [[lat[i],lon[i],pop[i]] for i in range(num)]    #將資料製作成[lats,lons,weights]的形式

map_osm = folium.Map(location=[35,110],zoom_start=5)    #繪製Map，開始縮放程度是5倍
HeatMap(data1).add_to(map_osm)  # 將熱力圖新增到前面建立的map裡

file_path = r"D:\Files\python\地圖\人口.html"
map_osm.save(file_path)     # 儲存為html檔案

webbrowser.open(file_path)  # 預設瀏覽器開啟
# Out:
# -----------------------------------------------------------------------
# FileNotFoundError                     Traceback (most recent call last)
# <ipython-input-33-022334318c76> in <module>
#       7 # posi=pd.read_csv("D:\\Files\\datasets\\CitiesLatLon_China.csv")
#       8
# ----> 9 posi=pd.read_excel("2015Cities-CHINA.xlsx")
#      10
#      11 num = 10
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
import pandas as pd
df = pd.read_csv("./foliumtestdata.csv")
df
# Out:
#    No     lat      lon     pop   yurusa
# 0   1  35.473  135.576   10000     5000
# 1   2  35.533  135.777  500000  7777777
# 2   3  35.300  135.400     300   776677
# 3   4  35.515  135.441   12112    88888
# 4   5  35.417  135.808  777777  7574764
# 5   6  35.667  135.678  123456  1234567
# 6   7  36.777  135.888  234567  2345678

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import folium
import webbrowser
from folium.plugins import HeatMap

import pandas as pd

# %%
yurusa_loc = []
for i in range(len(df)):
     for j in range(df.loc[i,'yurusa']):
        yurusa_loc.append([df.loc[i,'lat'],df.loc[i,'lon']])

# %%
# 目前總個案數
len(yurusa_loc)
# Out:
# 19803351

# %%
import folium
from folium.plugins import HeatMap
mapa = folium.Map(location=[35.473619099083784, 138.57622543781568],zoom_start=1.5,tiles='Stamen Toner')
HeatMap(yurusa_loc, radius=20).add_to(mapa)
mapa.save('yurusa_mapa.html')
mapa

# %%
mapa
