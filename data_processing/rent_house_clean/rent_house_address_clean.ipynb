# %% [markdown]
# ### 租房資料清整_1

# %%
import numpy as np
import pandas as pd

# %%
rent1=[]


for i in range (13,93):
    try:
        rent_house = pd.read_csv(f"./data/real_estate10{i}/a_lvr_land_c.csv")
#         print(rent_house)
        rent1.append(rent_house)
    except:
        print('abc')
# Out:
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc

# %%
len(rent1)
# Out:
# 31

# %%
rent2=pd.concat(rent1)
len(rent2)
# Out:
# 54933

# %%
# 寫出檔案
rent2.to_csv('台北租房資訊.csv',index=None)

# %% [markdown]
# ##### Linux 去除無建物的資料
#
# ##### grep "建物1" 台北租房資訊.csv > 台北1
# ##### cat 台北1 | wc -l
# ##### 將建物 2-22 從建物2-22棟 分別寫入檔案
# #####  grep "建物2" 台北租房資訊.csv >> 台北1
# ####   ...........
# #####  grep "建物22" 台北租房資訊.csv >> 台北1
# #####  cat 台北1 | wc -l
# #####  將 column 名稱加入新的 csv
# #####  head -n 1 台北租房資訊.csv > 台北2.csv
# #####  cat 台北2.csv
# #####  cat 台北1 >> 台北2.csv
# #####  head -n 2 台北2.csv

# %%
rent = pd.read_csv('台北2.csv')
rent
# Out:
# C:\Users\Student\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (5,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       鄉鎮市區          交易標的           土地區段位置建物區段門牌  土地面積平方公尺 都市土地使用分區 非都市土地使用分區  \
# 0      內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住       NaN
# 1      大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商       NaN
# 2      大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住       NaN
# 3      大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他       NaN
# 4      大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住       NaN
# ...    ...           ...                    ...       ...      ...       ...
# 52107  內湖區            建物      臺北市內湖區瑞光路601~630號      0.00        工       NaN
# 52108  南港區            建物     臺北市南港區經貿二路181~210號      0.00        商       NaN
# ...

# %%
# 去掉不要的欄位
rent2=rent.drop(['非都市土地使用分區', '非都市土地使用編定','備註','編號','車位面積平方公尺','車位類別','車位總額元','主要建材'], axis=1)
# 取代名稱
rent2.rename(columns={'土地區段位置建物區段門牌':'Ads','鄉鎮市區':'Area'}, inplace = True)
rent2.head(5)
# Out:
#   Area          交易標的                    Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 0  內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住  1010806
# 1  大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商  1010822
# 2  大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住  1010801
# 3  大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他  1010803
# 4  大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住  1010802
#
#        租賃筆棟數 租賃層次  總樓層數             建物型態  ...   建築完成年月 建物總面積平方公尺  建物現況格局-房  \
# 0  土地1建物1車位1   八層  11.0  住宅大樓(11層含以上有電梯)  ...  0980923     88.70         3
# 1  土地1建物1車位0   六層  12.0           辦公商業大樓  ...  0780615    143.62         0
# 2  土地1建物1車位0   三層  19.0  住宅大樓(11層含以上有電梯)  ...      NaN     73.19         2
# 3  土地1建物1車位0   九層  12.0  住宅大樓(11層含以上有電梯)  ...  0681020     54.05         1
# 4  土地1建物1車位0   二層   7.0    華廈(10層含以下有電梯)  ...  0721129    117.02         3
#
#    建物現況格局-廳  建物現況格局-衛  建物現況格局-隔間 有無管理組織 有無附傢俱    總額元  單價元平方公尺
# ...

# %%
# 建立路名欄位
Road=rent2.Ads.str.split('(?P<city>([\u4E00-\u9FFF]{2}(?=[\u7e23|\u5e02])[\u7e23|\u5e02])?(?P<dist>[\u4E00-\u5339\u5341-\u9FFF]+(?=[\u9109|\u93ae|\u5e02|\u5340])[\u9109|\u93ae|\u5e02|\u5340])*)?(?P<road>[\u4E00-\u9FFF]+(?!\d)(?=[\u8857|\u8def|\u5927\u9053])[\u8857|\u8def|\u5927\u9053])(?P<sec>\d\u6bb5)?(?P<secZH>[\u4e00|\u4e8c|\u4e09|\u56db|\u4e94|\u516d|\u4e03|\u516b|\u4e5d|\u5341]\u6bb5)?(?P<ln>\d+\u5df7)?(?P<lnZH>[\u4E00-\u9FFF]{2}\u5df7)?(?P<aly>\d+\u5f04)?(?P<number>\d+\~\d+\u865f)').str.get(4)
rent2['St1']=Road
rent2
# Out:
#       Area          交易標的                    Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 0      內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住  1010806
# 1      大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商  1010822
# 2      大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住  1010801
# 3      大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他  1010803
# 4      大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住  1010802
# ...    ...           ...                    ...       ...      ...      ...
# 52107  內湖區            建物      臺北市內湖區瑞光路601~630號      0.00        工  1040424
# 52108  南港區            建物     臺北市南港區經貿二路181~210號      0.00        商  1080704
# 52109  萬華區            建物     臺北市萬華區西寧南路121~150號      0.00        商  1090227
# 52110  內湖區  房地(土地+建物)+車位   臺北市內湖區堤頂大道二段211~240號   5275.95       其他  1021210
# 52111  中正區            建物      臺北市中正區中華路一段31~60號      0.00        商  1081008
#
# ...

# %%
rent_st1_null=rent2[(rent2['St1'].isnull()==True)]
rent_st1_null
# Out:
#       Area       交易標的                           Ads  土地面積平方公尺 都市土地使用分區  \
# 363    大安區         建物          臺北市大安區安和路一醹102巷1~30號      0.00        住
# 560    信義區         建物        臺北市信義區基隆路一段135巷三樓1~30號      0.00        商
# 586    大安區         建物          臺北市大安區復興南二段111巷1~30號      0.00        商
# 610    南港區  房地(土地+建物)         臺北市南港區忠孝東路六段398項1~30號     19.87        住
# 1177   大同區         建物            臺北市大同區承德一段77巷1~30號      0.00        商
# ...    ...        ...                           ...       ...      ...
# 51536  松山區         建物         臺北市松山區南京東路四段47及31~60號      0.00        商
# 51694  大安區         建物             臺北市大安區四維路25和1~30號      0.00        商
# 51841  大安區         建物          臺北市大安區新生南路三段16之1~30號      0.00        住
# 51981  大同區         建物  臺北市大同區重慶北路三段113之1及113之21~30號      0.00        商
# 52101  信義區         建物       臺北市信義區基隆路一段200和181~210號      0.00        商
#
#          租賃年月日       租賃筆棟數     租賃層次  總樓層數             建物型態  ... 建物總面積平方公尺  \
# ...

# %%
# 將地址空值寫出檔案，並觀察哪一些路名錯誤
rent_st1_null.to_csv('台北路名空值.csv',index=None)

# %%
# 刪除欄位st1
rent3=rent2.drop(['St1'], axis=1)
# 寫出檔案
rent3.to_csv('台北3.csv',index=None)
# 讀取檔案
rent = pd.read_csv('台北3.csv')
rent.head(5)
# Out:
# C:\Users\Student\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Area          交易標的                    Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 0  內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住  1010806
# 1  大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商  1010822
# 2  大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住  1010801
# 3  大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他  1010803
# 4  大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住  1010802
#
#        租賃筆棟數 租賃層次  總樓層數             建物型態  ...   建築完成年月 建物總面積平方公尺  建物現況格局-房  \
# 0  土地1建物1車位1   八層  11.0  住宅大樓(11層含以上有電梯)  ...  0980923     88.70         3
# 1  土地1建物1車位0   六層  12.0           辦公商業大樓  ...  0780615    143.62         0
# ...

# %%
# 取代重複區域名

rent["Ads"] = rent["Ads"].str.replace("中山區中山區","中山區")
rent["Ads"] = rent["Ads"].str.replace("中正區中正區","中正區")
rent["Ads"] = rent["Ads"].str.replace("內湖區內湖區","內湖區")
rent["Ads"] = rent["Ads"].str.replace("信義區信義區","信義區")
rent["Ads"] = rent["Ads"].str.replace("北投區北投區","北投區")
rent["Ads"] = rent["Ads"].str.replace("中山區內湖區","內湖區")
rent["Ads"] = rent["Ads"].str.replace("南港區南港區","南港區")
rent["Ads"] = rent["Ads"].str.replace("大安區大安區","大安區")
rent["Ads"] = rent["Ads"].str.replace("士林區士林區","士林區")
rent["Ads"] = rent["Ads"].str.replace("文山區文山區","文山區")
rent["Ads"] = rent["Ads"].str.replace("松山區松山區","松山區")
rent["Ads"] = rent["Ads"].str.replace("大同區大同區","大同區")

rent["Ads"] = rent["Ads"].str.replace("臺北市中山區臺北市中山區","臺北市中山區")
rent["Ads"] = rent["Ads"].str.replace("臺北市中正區臺北市中正區","臺北市中正區")
rent["Ads"] = rent["Ads"].str.replace("臺北市內湖區臺北市內湖區","臺北市內湖區")
rent["Ads"] = rent["Ads"].str.replace("臺北市信義區臺北市信義區","臺北市信義區")
rent["Ads"] = rent["Ads"].str.replace("臺北市北投區臺北市北投區","臺北市北投區")
rent["Ads"] = rent["Ads"].str.replace("臺北市中山區臺北市內湖區","臺北市內湖區")
rent["Ads"] = rent["Ads"].str.replace("臺北市南港區臺北市南港區","臺北市南港區")
rent["Ads"] = rent["Ads"].str.replace("臺北市大安區臺北市大安區","臺北市大安區")
rent["Ads"] = rent["Ads"].str.replace("臺北市士林區臺北市士林區","臺北市士林區")
rent["Ads"] = rent["Ads"].str.replace("臺北市文山區臺北市文山區","臺北市文山區")
rent["Ads"] = rent["Ads"].str.replace("臺北市松山區臺北市松山區","臺北市松山區")
rent["Ads"] = rent["Ads"].str.replace("臺北市大同區臺北市大同區","臺北市大同區")

# %%
# 取代錯誤路名
rent["Ads"] = rent["Ads"].str.replace("ㄧ段","一段")
rent["Ads"] = rent["Ads"].str.replace("ㄧ路","一路")

# %%
# 取代錯誤路名

rent["Ads"] = rent["Ads"].str.replace("臺北市大安區安和路一醹102巷1~30號","臺北市大安區安和路一段102巷1~30號")
rent["Ads"] = rent["Ads"].str.replace("臺北
")
rent["Ads"] = rent["Ads"].str.replace("臺北市大安區四維路25和1~30號","臺北市大安區四維路1~30號")
rent["Ads"] = rent["Ads"].str.replace("臺北市中山區農安街之1~30號","臺北市中山區農安街1~30號")
rent["Ads"] = rent["Ads"].str.replace("臺北市南港區舊莊街一段三巷1~30號","臺北市南港區舊莊街一段3巷1~30號")
rent["Ads"] = rent["Ads"].str.replace("臺北市大同區重慶北路三段113之1及113之21~30號","臺北市大同區重慶北路三段113之21~30號")
rent["Ads"] = rent["Ads"].str.replace("臺北市松山區敦化北199巷1~30號","臺北市松山區敦化北路199巷1~30號")
rent["Ads"] = rent["Ads"].str.replace("臺北市南港區忠孝東路六段398項1~30號","臺北市南港區忠孝東路六段398巷1~30號")

# %%
# 創路名的欄位
Road=rent.Ads.str.split('(?P<city>[\u4E00-\u9FFF]{2}(?=[\u7e23|\u5e02])[\u7e23|\u5e02])?(?P<dist>[\u4E00-\u5339\u5341-\u9FFF]+(?=[\u9109|\u93ae|\u5e02|\u5340])[\u9109|\u93ae|\u5e02|\u5340])?(?P<road>[\u4E00-\u9FFF]+(?!\d)(?=[\u8857|\u8def|\u5927\u9053])[\u8857|\u8def|\u5927\u9053])(?P<sec>\d\u6bb5)?(?P<secZH>[\u4e00|\u4e8c|\u4e09|\u56db|\u4e94|\u516d|\u4e03|\u516b|\u4e5d|\u5341]\u6bb5)?(?P<ln>\d+\u5df7)?(?P<lnZH>[\u4E00-\u9FFF]{2}\u5df7)?(?P<aly>\d+\u5f04)?((?P<number>\d+\~\d+\u865f)|(?P<number1>\d+\u865f)|(?P<zhi>\d+\u4e4b\d+\~\d+\u865f))').str.get(3)
rent['St']=Road
rent
# Out:
#       Area          交易標的                    Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 0      內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住  1010806
# 1      大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商  1010822
# 2      大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住  1010801
# 3      大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他  1010803
# 4      大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住  1010802
# ...    ...           ...                    ...       ...      ...      ...
# 52107  內湖區            建物      臺北市內湖區瑞光路601~630號      0.00        工  1040424
# 52108  南港區            建物     臺北市南港區經貿二路181~210號      0.00        商  1080704
# 52109  萬華區            建物     臺北市萬華區西寧南路121~150號      0.00        商  1090227
# 52110  內湖區  房地(土地+建物)+車位   臺北市內湖區堤頂大道二段211~240號   5275.95       其他  1021210
# 52111  中正區            建物      臺北市中正區中華路一段31~60號      0.00        商  1081008
#
# ...

# %%
# 檢查有無空值
rent2=rent[(rent['St'].isnull()==True)]
rent2
# Out:
#       Area       交易標的                       Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 3584   內湖區         建物  臺北市內湖區民權東路六段123巷20?1~30號      0.00        商  1020318
# 7595   松山區         建物  臺北市松山區民生東路三段129?121~150號      0.00        住  1021111
# 9513   中山區         建物            臺北市中山區德?街1~30號      0.00        商  1030329
# 9929   信義區         建物               臺北市信義區松德路樓號      0.00       其他  1030414
# 10089  中山區         建物             臺北市中山區伊通街十樓之號      0.00        住  1030417
# 10504  中山區         建物                臺北市中山區龍江路號      0.00        住  1030524
# 13756  信義區         建物   臺北市信義區忠孝東?五段71巷12?1~30號      0.00        住  1031104
# 15253  大安區         建物            臺北市大安區151~180號      0.00      NaN  1040311
# 16581  大安區         建物               臺北市大安區忠孝東路號      0.00        商  1040520
# 19375  中正區         建物           臺北市中正區170巷1~30號    496.00        住  1041022
# 21103  大安區         建物            臺北市大安區濟南路三段四樓號     65.64        住  1050120
# ...

# %%
# 去掉無法知道正確路名或地址的 row
rent3 = rent.drop([9929, 10089,10504,15253,16581,19375,21103,23236,27364,31852,32063,32551,42216,44146])
rent3
# Out:
#       Area          交易標的                    Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 0      內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住  1010806
# 1      大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商  1010822
# 2      大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住  1010801
# 3      大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他  1010803
# 4      大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住  1010802
# ...    ...           ...                    ...       ...      ...      ...
# 52107  內湖區            建物      臺北市內湖區瑞光路601~630號      0.00        工  1040424
# 52108  南港區            建物     臺北市南港區經貿二路181~210號      0.00        商  1080704
# 52109  萬華區            建物     臺北市萬華區西寧南路121~150號      0.00        商  1090227
# 52110  內湖區  房地(土地+建物)+車位   臺北市內湖區堤頂大道二段211~240號   5275.95       其他  1021210
# 52111  中正區            建物      臺北市中正區中華路一段31~60號      0.00        商  1081008
#
# ...

# %%
# 檢查空值

rent4=rent3[(rent3['St'].isnull()==True)]
rent4
# Out:
#       Area 交易標的                       Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 3584   內湖區   建物  臺北市內湖區民權東路六段123巷20?1~30號       0.0        商  1020318
# 7595   松山區   建物  臺北市松山區民生東路三段129?121~150號       0.0        住  1021111
# 9513   中山區   建物            臺北市中山區德?街1~30號       0.0        商  1030329
# 13756  信義區   建物   臺北市信義區忠孝東?五段71巷12?1~30號       0.0        住  1031104
# 37578  北投區   建物       臺北市北投區公?路161巷31~60號       0.0        住  1070611
# 37792  北投區   建物      臺北市北投區公?路376巷2弄1~30號       0.0        住  1070620
# 40285  北投區   建物     臺北市北投區公?路209巷36弄1~30號       0.0        住  1071101
# 44091  北投區   建物        臺北市北投區公?路209巷1~30號       0.0        住  1080517
# 48180  北投區   建物           臺北市北投區公?路31~60號       0.0        住  1081129
# 48439  北投區   建物         臺北市北投區公?路151~180號       0.0        住  1081222
# 48658  北投區   建物        臺北市北投區公?路276巷1~30號       0.0        住  1090116
# 49516  北投區   建物        臺北市北投區公?路276巷1~30號       0.0        住  1090310
#
# ...

# %%
# ? 無法取代，故寫出檔案手動修改 
rent3.to_csv('台北4.csv',index=None)

# %%
rent = pd.read_csv('台北5.csv')
rent.head(5)
# Out:
# C:\Users\Student\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Area          交易標的                    Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 0  內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住  1010806
# 1  大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商  1010822
# 2  大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住  1010801
# 3  大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他  1010803
# 4  大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住  1010802
#
#        租賃筆棟數 租賃層次  總樓層數             建物型態  ... 建物總面積平方公尺 建物現況格局-房  建物現況格局-廳  \
# 0  土地1建物1車位1   八層  11.0  住宅大樓(11層含以上有電梯)  ...     88.70        3         2
# 1  土地1建物1車位0   六層  12.0           辦公商業大樓  ...    143.62        0         2
# ...

# %%
Road=rent.Ads.str.split('(?P<city>[\u4E00-\u9FFF]{2}(?=[\u7e23|\u5e02])[\u7e23|\u5e02])?(?P<dist>[\u4E00-\u5339\u5341-\u9FFF]+(?=[\u9109|\u93ae|\u5e02|\u5340])[\u9109|\u93ae|\u5e02|\u5340])?(?P<road>[\u4E00-\u9FFF]+(?!\d)(?=[\u8857|\u8def|\u5927\u9053])[\u8857|\u8def|\u5927\u9053])(?P<sec>\d\u6bb5)?(?P<secZH>[\u4e00|\u4e8c|\u4e09|\u56db|\u4e94|\u516d|\u4e03|\u516b|\u4e5d|\u5341]\u6bb5)?(?P<ln>\d+\u5df7)?(?P<lnZH>[\u4E00-\u9FFF]{2}\u5df7)?(?P<aly>\d+\u5f04)?((?P<number>\d+\~\d+\u865f)|(?P<number1>\d+\u865f)|(?P<zhi>\d+\u4e4b\d+\~\d+\u865f))').str.get(3)
rent['St']=Road
rent
# Out:
#       Area          交易標的                    Ads  土地面積平方公尺 都市土地使用分區    租賃年月日  \
# 0      內湖區  房地(土地+建物)+車位  臺北市內湖區內湖路二段253巷31~60號   4065.00        住  1010806
# 1      大安區     房地(土地+建物)      臺北市大安區和平東路一段1~30號     12.65        商  1010822
# 2      大安區     房地(土地+建物)      臺北市大安區安和路二段31~60號      7.09        住  1010801
# 3      大安區     房地(土地+建物)     臺北市大安區和平東路三段61~90號      4.43       其他  1010803
# 4      大安區     房地(土地+建物)  臺北市大安區建國南路二段294巷1~30號     23.27        住  1010802
# ...    ...           ...                    ...       ...      ...      ...
# 52093  內湖區            建物      臺北市內湖區瑞光路601~630號      0.00        工  1040424
# 52094  南港區            建物     臺北市南港區經貿二路181~210號      0.00        商  1080704
# 52095  萬華區            建物     臺北市萬華區西寧南路121~150號      0.00        商  1090227
# 52096  內湖區  房地(土地+建物)+車位   臺北市內湖區堤頂大道二段211~240號   5275.95       其他  1021210
# 52097  中正區            建物      臺北市中正區中華路一段31~60號      0.00        商  1081008
#
# ...

# %%
# 檢查無空值
rent2=rent[(rent['St'].isnull()==True)]
rent2
# Out:
# Empty DataFrame
# Columns: [Area, 交易標的, Ads, 土地面積平方公尺, 都市土地使用分區, 租賃年月日, 租賃筆棟數, 租賃層次, 總樓層數, 建物型態, 主要用途, 建築完成年月, 建物總面積平方公尺, 建物現況格局-房, 建物現況格局-廳, 建物現況格局-衛, 建物現況格局-隔間, 有無管理組織, 有無附傢俱, 總額元, 單價元平方公尺, St]
# Index: []
#
# [0 rows x 22 columns]

# %%
rent.to_csv('台北5.csv',index=None)
